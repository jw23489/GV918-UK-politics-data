# %% [markdown]
# # Instruction
#
# In this assignment, you will analyze the political tweets during the campaign of the 2017 UK General Election. The Twitter database, in SQLite format, is available at the link below (it's zipped, so you need to decompress before working on it).
#
# https://www.dropbox.com/s/jh40sd8xebjg9pn/ge_2017.sqlite.zip?dl=1
#
#
# ## Data description
#
# When I collected the data, I saved the streamed Twitter data every 15 minutes. The condition of streaming is to get all tweets from the candidates and party official accounts and replies/retweets to the tweets from these accounts. I randomly selected 10 percent of the data files for this assignment.
#
# After selecting the data I created two tables from the data, one for twitter content, and another for user information. All the field names are original names from Twitter JSON, so it should be easy to understand the contents. I added one field to the user table, which is `screen_name_in` where the value 1 indicates the election candidates' or party official accounts. 0 indicates otherwise.

# %% [markdown]
# # Load packages

# %%
import pandas as pd
import sqlite3

# %%
# !wget https://www.dropbox.com/s/jh40sd8xebjg9pn/ge_2017.sqlite.zip?dl=1
# Out:
# --2023-12-31 10:55:41--  https://www.dropbox.com/s/jh40sd8xebjg9pn/ge_2017.sqlite.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/jh40sd8xebjg9pn/ge_2017.sqlite.zip [following]
# --2023-12-31 10:55:42--  https://www.dropbox.com/s/dl/jh40sd8xebjg9pn/ge_2017.sqlite.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce75ee9dad0860fd17b016e5d95.dl.dropboxusercontent.com/cd/0/get/CKe2LmAXyyYpnxrIdPuDSO3zMu66XGc3aIGJ4Tlo4jA8HzcLRoodVoDL8HvgKvM_TCnIpAmLCIB7ztMw9Z68mGUIgUO4x9vY5Vx_THx5xmWcqkc61ppUNf73VjHdvPGpniWHQ3n_X5ZuqOUha63vzRzz/file?dl=1# [following]
# --2023-12-31 10:55:42--  https://uce75ee9dad0860fd17b016e5d95.dl.dropboxusercontent.com/cd/0/get/CKe2LmAXyyYpnxrIdPuDSO3zMu66XGc3aIGJ4Tlo4jA8HzcLRoodVoDL8HvgKvM_TCnIpAmLCIB7ztMw9Z68mGUIgUO4x9vY5Vx_THx5xmWcqkc61ppUNf73VjHdvPGpniWHQ3n_X5ZuqOUha63vzRzz/file?dl=1
# Resolving uce75ee9dad0860fd17b016e5d95.dl.dropboxusercontent.com (uce75ee9dad0860fd17b016e5d95.dl.dropboxusercontent.com)... 162.125.2.15, 2620:100:6017:15::a27d:20f
# Connecting to uce75ee9dad0860fd17b016e5d95.dl.dropboxusercontent.com (uce75ee9dad0860fd17b016e5d95.dl.dropboxusercontent.com)|162.125.2.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31772915 (30M) [application/binary]
# Saving to: ‘ge_2017.sqlite.zip?dl=1.1’
#
# ge_2017.sqlite.zip? 100%[===================>]  30.30M  69.9MB/s    in 0.4s
#
# 2023-12-31 10:55:43 (69.9 MB/s) - ‘ge_2017.sqlite.zip?dl=1.1’ saved [31772915/31772915]

# %%
# !unzip ge_2017.sqlite.zip\?dl\=1
# Out:
# Archive:  ge_2017.sqlite.zip?dl=1
# replace ge_2017.sqlite? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# # Connect to the database (2 percent)

# %%
con_ge = sqlite3.connect('ge_2017.sqlite')

# %% [markdown]
# # Check the database (5 percent)
#
# How many tweets are in the tweet table? How many users in the users table?

# %%
df_tab_info = pd.read_sql_query("SELECT * FROM sqlite_master WHERE type='table'", con_ge)
df_tab_info
# using pd.read to read the sqlite master table. This tells me how many tables are in this dataset. There are 2
# Out:
#     type    name tbl_name  rootpage  \
# 0  table  tweets   tweets         2
# 1  table   users    users     21681
#
#                                                  sql
# 0  CREATE TABLE `tweets` (\n  `doc_id` TEXT,\n  `...
# 1  CREATE TABLE `users` (\n  `verified` INTEGER,\...

# %%
print(df_tab_info['sql'][0])
#checking fields in tweets table for future referecne
# Out:
# CREATE TABLE `tweets` (
#   `doc_id` TEXT,
#   `text` TEXT,
#   `retweet_count` REAL,
#   `favorite_count` REAL,
#   `favorited` INTEGER,
#   `truncated` INTEGER,
#   `id_str` TEXT,
#   `in_reply_to_screen_name` TEXT,
#   `source` TEXT,
#   `retweeted` INTEGER,
#   `created_at` TEXT,
#   `in_reply_to_status_id_str` TEXT,
#   `in_reply_to_user_id_str` TEXT,
#   `lang` TEXT,
#   `listed_count` REAL,
#   `user_id_str` TEXT,
#   `country_code` TEXT,
#   `country` TEXT,
#   `place_type` TEXT,
#   `full_name` TEXT,
#   `place_name` TEXT,
#   `place_id` TEXT,
#   `place_lat` REAL,
#   `place_lon` REAL,
#   `lat` REAL,
#   `lon` REAL,
#   `expanded_url` TEXT,
#   `url` TEXT,
#   `created_at_dt` REAL
# )

# %%
pd.read_sql_query("SELECT * FROM tweets LIMIT 5", con_ge)
# Out:
#                           doc_id  \
# 0  tw_json_6_201705261745.json.1
# 1  tw_json_6_201705261745.json.2
# 2  tw_json_6_201705261745.json.3
# 3  tw_json_6_201705261745.json.4
# 4  tw_json_6_201705261745.json.5
#
#                                                 text  retweet_count  \
# 0  RT @BenRich66: If you work in tech and are bac...            0.0
# 1  RT @AngelaRayner: Whilst polls can fluctuate i...            0.0
# 2  RT @aw_bell: We must defend our freedoms from ...            0.0
# 3  RT @UKLabour: Education should be available to...            0.0
# 4  RT @RichardBurgon: The stakes are high in this...            0.0
#
#    favorite_count  favorited  truncated              id_str  \
# 0             0.0          0          0  868157285226491905
# 1             0.0          0          0  868157291270467584
# 2             0.0          0          0  868157295083102210
# 3             0.0          0          0  868157295938633729
# 4             0.0          0          0  868157297750671361
#
#   in_reply_to_screen_name                                             source  \
# 0                    None  <a href="http://twitter.com/download/iphone" r...
# 1                    None  <a href="https://www.chicmi.com/" rel="nofollo...
# 2                    None  <a href="http://twitter.com/download/android" ...
# 3                    None  <a href="http://twitter.com/download/iphone" r...
# 4                    None  <a href="http://twitter.com/#!/download/ipad" ...
#
#    retweeted  ... full_name place_name place_id place_lat  place_lon   lat  \
# 0          0  ...      None       None     None      None       None  None
# 1          0  ...      None       None     None      None       None  None
# 2          0  ...      None       None     None      None       None  None
# 3          0  ...      None       None     None      None       None  None
# 4          0  ...      None       None     None      None       None  None
#
#     lon                                       expanded_url  \
# 0  None     http://www.libdems.org.uk/tech-backing-libdems
# 1  None                                               None
# 2  None                                               None
# 3  None                                               None
# 4  None  https://twitter.com/i/web/status/8681572979813...
#
#                        url created_at_dt
# 0  https://t.co/tWDj1dWU6R  1.495820e+09
# 1                     None  1.495820e+09
# 2                     None  1.495820e+09
# 3                     None  1.495820e+09
# 4                           1.495820e+09
#
# [5 rows x 29 columns]

# %%
pd.read_sql_query("SELECT * FROM users LIMIT 5", con_ge)
# Out:
#    verified                       location user_id_str  \
# 0         0            Mostly in Liverpool    20255744
# 1         0                     London, UK  1871497250
# 2         0  Easton/Lawrence Hill, Bristol   427599291
# 3         0                  Bury, England   317402880
# 4         0                           None  4309416083
#
#                                          description  geo_enabled  \
# 0  Leader Liverpool Lib Dems, Lib Dem Spokesperso...            1
# 1  I tweet the top stories that Westminster are t...            0
# 2                 Field Organiser for @TheGreenParty            1
# 3  Chippy Yorkshireman, Labour & Remain supporter...            0
# 4                                               None            0
#
#                   user_created_at  statuses_count  followers_count  \
# 0  Fri Feb 06 17:54:34 +0000 2009         42343.0           3914.0
# 1  Mon Sep 16 12:33:23 +0000 2013          9262.0            258.0
# 2  Sat Dec 03 18:43:42 +0000 2011         39943.0           5595.0
# 3  Tue Jun 14 21:51:59 +0000 2011          4060.0            145.0
# 4  Sat Nov 28 17:43:36 +0000 2015         26420.0            270.0
#
#    favourites_count  protected                   user_url              name  \
# 0             158.0          0  http://richardkemp.org.uk  Richard Kemp CBE
# 1           23407.0          0                       None           govmixx
# 2            2390.0          0      http://robtelford.com       Rob Telford
# 3            2937.0          0                       None       Manumission
# 4           14127.0          0                       None       Donald Duck
#
#    time_zone user_lang  utc_offset  friends_count      screen_name  \
# 0  Amsterdam        en      7200.0          632.0         cllrkemp
# 1       None        en         NaN          865.0          govmixx
# 2     London        en      3600.0         4819.0  GreenRobTelford
# 3       None        en         NaN          312.0     lockforward4
# 4     London     en-gb      3600.0          435.0  maninthestreet9
#
#    user_created_at_dt  screen_name_in
# 0        1.233943e+09               1
# 1        1.379335e+09               0
# 2        1.322938e+09               0
# 3        1.308088e+09               0
# 4        1.448733e+09               0

# %%
print(df_tab_info['sql'][1])
#checking fields in users table for future reference
# Out:
# CREATE TABLE `users` (
#   `verified` INTEGER,
#   `location` TEXT,
#   `user_id_str` TEXT,
#   `description` TEXT,
#   `geo_enabled` INTEGER,
#   `user_created_at` TEXT,
#   `statuses_count` REAL,
#   `followers_count` REAL,
#   `favourites_count` REAL,
#   `protected` INTEGER,
#   `user_url` TEXT,
#   `name` TEXT,
#   `time_zone` TEXT,
#   `user_lang` TEXT,
#   `utc_offset` REAL,
#   `friends_count` REAL,
#   `screen_name` TEXT,
#   `user_created_at_dt` REAL,
#   `screen_name_in` INTEGER
# )

# %%
pd.read_sql_query("""
SELECT COUNT (*)
FROM tweets
""", con_ge)
# From the previous query, I know have the names of the tables, thus I can make queries on the individual tabkes
# Out:
#    COUNT (*)
# 0     221711

# %% [markdown]
# There are 221,711 tweets in the table

# %%
pd.read_sql_query("""
SELECT COUNT (*)
FROM users
""", con_ge)
# Out:
#    COUNT (*)
# 0      91256

# %% [markdown]
# There are 91,256 users in the table

# %% [markdown]
# # Description of the data (21 percent, 3 per question)
#
# Answer the following questions (try to do the most computation in the query, if you do some work in Python, you will only get partial credit):
#
# 1. Which screen_name has the highest count of tweets?
# 2. Who has the highest number of followers?
# 3. Among politicians, who has the highest number of followers?
# 4. Which tweet has the earliest timestamp in the data? Which is the latest?
# 5. Who were the top ten most replied accounts? How many times?
# 6. How many tweets with the word Brexit?
# 7. How many tweets have geolocation information (`lat` or `lon` value)?

# %%
# 1. Max count of tweets
# Using field status_count as number of tweets
pd.read_sql_query("SELECT MAX(statuses_count) FROM users", con_ge)
# Out:
#    MAX(statuses_count)
# 0            3256136.0

# %%
#finding the exact screen name with that tweet count

pd.read_sql_query("""
SELECT*
FROM users
WHERE statuses_count = 3256136.0
""", con_ge)
# Out:
#    verified   location user_id_str  \
# 0         0  愛媛県 Japan    93196638
#
#                                          description  geo_enabled  \
# 0  MacBook Proユーザ。音楽とサッカー（とその他スポーツ）と猫関係のツイート、リツイー...            0
#
#                   user_created_at  statuses_count  followers_count  \
# 0  Sat Nov 28 14:49:44 +0000 2009       3256136.0           4768.0
#
#    favourites_count  protected                                 user_url name  \
# 0              68.0          0  http://hisashitoshima.cocolog-nifty.com  としま
#
#   time_zone user_lang  utc_offset  friends_count screen_name  \
# 0     Tokyo        en     32400.0          550.0   t_hisashi
#
#    user_created_at_dt  screen_name_in
# 0        1.259420e+09               0

# %% [markdown]
# The screen name with the highest tweet count of 3,256,136 is t_hisashi.

# %%
# 2. Highest number of followers

pd.read_sql_query("SELECT MAX(followers_count) FROM users", con_ge)
# Out:
#    MAX(followers_count)
# 0            12419966.0

# %%
# Finding the specific user with the highest no. of followers

pd.read_sql_query("""
SELECT *
FROM users
WHERE followers_count = 12419966.0
""", con_ge)
# Out:
#    verified location user_id_str  \
# 0         1   Earth     20015311
#
#                                          description  geo_enabled  \
# 0  Godless Ape. Comedian, Actor, Screenwriter, Mo...            1
#
#                   user_created_at  statuses_count  followers_count  \
# 0  Wed Feb 04 00:00:12 +0000 2009         43211.0       12419966.0
#
#    favourites_count  protected                     user_url           name  \
# 0           23623.0          0  http://www.rickygervais.com  Ricky Gervais
#
#   time_zone user_lang  utc_offset  friends_count   screen_name  \
# 0    London        en      3600.0         1156.0  rickygervais
#
#    user_created_at_dt  screen_name_in
# 0        1.233706e+09               0

# %% [markdown]
# Ricky Gervais has the highest number of followers, which is 12,419,966.
# ---

# %%
# 3. Highest followers among the politicians
# here, I must filter the results using the added column screen_name_in the users table.
# I seek the highest number of followers where the screen_name_in value is 1 (denotes politician)

pd.read_sql_query("""
SELECT MAX(followers_count)
FROM users
WHERE screen_name_in = 1
""", con_ge)
# Out:
#    MAX(followers_count)
# 0              968629.0

# %%
# Finding the specific politian with highers no. of followers

pd.read_sql_query("""
SELECT *
FROM users
WHERE followers_count = 968629.0
""", con_ge)
# Out:
#    verified location user_id_str  \
# 0         1       UK   117777690
#
#                                          description  geo_enabled  \
# 0  Leader of the Labour Party. Support our #GE201...            0
#
#                   user_created_at  statuses_count  followers_count  \
# 0  Fri Feb 26 15:45:23 +0000 2010          7878.0         968629.0
#
#    favourites_count  protected                               user_url  \
# 0             125.0          0  http://www.labour.org.uk/volunteering
#
#             name time_zone user_lang  utc_offset  friends_count   screen_name  \
# 0  Jeremy Corbyn    London        en      3600.0         2424.0  jeremycorbyn
#
#    user_created_at_dt  screen_name_in
# 0        1.267199e+09               1

# %% [markdown]
# Jeremy Corbyn is the politician with the highest number of followers, which is 968,629.

# %%
#4. Tweet with earliest timestamp
# using the created_at_dt field in the tweets table
# using MIN function to show the earliest number

pd.read_sql_query("SELECT MIN(created_at_dt) FROM tweets", con_ge)
# Out:
#    MIN(created_at_dt)
# 0        1.495820e+09

# %%
# the specific tweet

pd.read_sql_query("""
SELECT *
FROM tweets
WHERE created_at_dt = 1.495820e+09
""", con_ge)
# Out:
#                             doc_id  \
# 0  tw_json_6_201705261745.json.304
#
#                                                 text  retweet_count  \
# 0  RT @daily_politics: "Maybe we should just stop...            0.0
#
#    favorite_count  favorited  truncated              id_str  \
# 0             0.0          0          0  868158123072159744
#
#   in_reply_to_screen_name                                             source  \
# 0                    None  <a href="http://twitter.com/download/android" ...
#
#    retweeted  ... full_name place_name place_id place_lat  place_lon   lat  \
# 0          0  ...      None       None     None      None       None  None
#
#     lon                                       expanded_url url created_at_dt
# 0  None  https://twitter.com/MammothWhale/status/868146...      1.495820e+09
#
# [1 rows x 29 columns]

# %%
# 4. Tweet with latest timestamp
# using MAX function to show the latest number

pd.read_sql_query("SELECT MAX(created_at_dt) FROM tweets", con_ge)
# Out:
#    MAX(created_at_dt)
# 0        1.496910e+09

# %%
# the specific tweet

pd.read_sql_query("""
SELECT *
FROM tweets
WHERE created_at_dt = 1.496910e+09
""", con_ge)
# Out:
# Empty DataFrame
# Columns: [doc_id, text, retweet_count, favorite_count, favorited, truncated, id_str, in_reply_to_screen_name, source, retweeted, created_at, in_reply_to_status_id_str, in_reply_to_user_id_str, lang, listed_count, user_id_str, country_code, country, place_type, full_name, place_name, place_id, place_lat, place_lon, lat, lon, expanded_url, url, created_at_dt]
# Index: []
#
# [0 rows x 29 columns]

# %%
# 5. Top ten most replied accounts

# %%
#6. No. of tweets with word Brexit

pd.read_sql_query("""
SELECT COUNT (*)
 FROM tweets
 WHERE text LIKE '%Brexit%'
 """, con_ge)
# Out:
#    COUNT (*)
# 0       9028

# %% [markdown]
# There are 9,028 tweets that mention Brexit

# %%
#7. How many tweets have geolocation information (lat or lon value)?

pd.read_sql_query("""
SELECT COUNT (*)
FROM tweets
WHERE lat
""", con_ge)
# Out:
#    COUNT (*)
# 0         35

# %%
pd.read_sql_query("""
SELECT COUNT (*)
FROM tweets
WHERE lon
""", con_ge)
# Out:
#    COUNT (*)
# 0         35

# %% [markdown]
# 35 tweets have geolocation information.

# %% [markdown]
# # Use of hashtags (10 percent)
#
# In this section, you will work on hashtags in tweets. If you are not sure what is hashtags, please refer to: https://business.twitter.com/en/blog/how-to-create-and-use-hashtags.html
#
# ### Tasks:
#
# 1. Think about the ways to extract hashtags from the Twitter text. The goal here is to create a two-column DataFrame where the first column is tweet id (`id_str`) and the second column is the content of the hashtag (e.g. `#ge2017`, `#conservative`).
#
# 2. Using the dataframe and the database, find the following:
#   - What are the 10 most popular hashtags?
#   - What are the 10 most popular hashtags by political Twitter accounts (i.e. election candidates/parties)? What about non-politician/parties account?

# %%
pd.read_sql_query("SELECT text FROM tweets", con_ge)
# Out:
#                                                      text
# 0       RT @BenRich66: If you work in tech and are bac...
# 1       RT @AngelaRayner: Whilst polls can fluctuate i...
# 2       RT @aw_bell: We must defend our freedoms from ...
# 3       RT @UKLabour: Education should be available to...
# 4       RT @RichardBurgon: The stakes are high in this...
# ...                                                   ...
# 221706  RT @jeremycorbyn: We've left no place and no s...
# 221707                    @jaybn1 Thank you so much Jay x
# 221708  @jeremycorbyn @UKLabour Thank you Jeremy and t...
# 221709  RT @Conservatives: TM: We cannot and must not ...
# 221710  RT @anna_firth: In Richmond Park only @ZacGold...
#
# [221711 rows x 1 columns]

# %%
pd.read_sql_query("""
SELECT *
 FROM tweets
 WHERE text LIKE '%#%'
 """, con_ge)
# Out:
#                                  doc_id  \
# 0         tw_json_6_201705261745.json.5
# 1         tw_json_6_201705261745.json.9
# 2        tw_json_6_201705261745.json.10
# 3        tw_json_6_201705261745.json.11
# 4        tw_json_6_201705261745.json.16
# ...                                 ...
# 65964  tw_json_6_201706080815.json.5642
# 65965  tw_json_6_201706080815.json.5643
# 65966  tw_json_6_201706080815.json.5650
# 65967  tw_json_6_201706080815.json.5651
# 65968  tw_json_6_201706080815.json.5656
#
#                                                     text  retweet_count  \
# 0      RT @RichardBurgon: The stakes are high in this...            0.0
# 1      Less than 2 weeks until #GE2017. Team #Cherry4...            0.0
# 2      Why people are voting Labour in Harborough #GE...            0.0
# 3      RT @Conservatives: Your vote at #GE2017 will h...            0.0
# 4      RT @hazel_thorpe: Self interest ? @OliHenman @...            0.0
# ...                                                  ...            ...
# 65964  RT @UKLabour: #VoteLabour today for a fairer B...            0.0
# 65965  RT @ChriswMP: The vile disgusting S*n is at it...            0.0
# 65966  @UKLabour Only a vote for labour can stop the ...            0.0
# 65967  RT @Stortlibdems: Vote Mark Argent for Hertfor...            0.0
# 65968  RT @anna_firth: In Richmond Park only @ZacGold...            0.0
#
#        favorite_count  favorited  truncated              id_str  \
# 0                 0.0          0          0  868157297750671361
# 1                 0.0          0          0  868157303651840000
# 2                 0.0          0          0  868157299021553664
# 3                 0.0          0          0  868157309171752961
# 4                 0.0          0          0  868157323465953282
# ...               ...        ...        ...                 ...
# 65964             0.0          0          0  872728646183784448
# 65965             0.0          0          0  872728646854864897
# 65966             0.0          0          0  872728651716067328
# 65967             0.0          0          0  872728652127055873
# 65968             0.0          0          0  872728655876820992
#
#       in_reply_to_screen_name  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# ...                       ...
# 65964                    None
# 65965                    None
# 65966                UKLabour
# 65967                    None
# 65968                    None
#
#                                                   source  retweeted  ...  \
# 0      <a href="http://twitter.com/#!/download/ipad" ...          0  ...
# 1      <a href="https://ads.twitter.com" rel="nofollo...          0  ...
# 2      <a href="https://twittimer.com" rel="nofollow"...          0  ...
# 3      <a href="http://twitter.com/download/android" ...          0  ...
# 4      <a href="http://twitter.com/download/android" ...          0  ...
# ...                                                  ...        ...  ...
# 65964  <a href="http://twitter.com/download/android" ...          0  ...
# 65965  <a href="https://mobile.twitter.com" rel="nofo...          0  ...
# 65966  <a href="http://twitter.com/#!/download/ipad" ...          0  ...
# 65967  <a href="http://twitter.com/download/iphone" r...          0  ...
# 65968  <a href="http://twitter.com/download/android" ...          0  ...
#
#       full_name place_name place_id place_lat  place_lon lat lon  \
# 0          None       None     None       NaN        NaN NaN NaN
# 1          None       None     None       NaN        NaN NaN NaN
# 2          None       None     None       NaN        NaN NaN NaN
# 3          None       None     None       NaN        NaN NaN NaN
# 4          None       None     None       NaN        NaN NaN NaN
# ...         ...        ...      ...       ...        ...  ..  ..
# 65964      None       None     None       NaN        NaN NaN NaN
# 65965      None       None     None       NaN        NaN NaN NaN
# 65966      None       None     None       NaN        NaN NaN NaN
# 65967      None       None     None       NaN        NaN NaN NaN
# 65968      None       None     None       NaN        NaN NaN NaN
#
#                                             expanded_url  \
# 0      https://twitter.com/i/web/status/8681572979813...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 65964  https://twitter.com/LadPolitics/status/8723970...
# 65965  https://twitter.com/marcjacobleo/status/872727...
# 65966                                               None
# 65967                                               None
# 65968                              http://bit.ly/2s0qDvb
#
#                            url created_at_dt
# 0                               1.495820e+09
# 1                         None  1.495820e+09
# 2                         None  1.495820e+09
# 3                         None  1.495820e+09
# 4                         None  1.495820e+09
# ...                        ...           ...
# 65964  https://t.co/953WYc2p0c  1.496910e+09
# 65965  https://t.co/0pkGkNSaYE  1.496910e+09
# 65966                     None  1.496910e+09
# 65967                     None  1.496910e+09
# 65968                           1.496910e+09
#
# [65969 rows x 29 columns]

# %%
pd.read_sql_query("""
SELECT DISTINCT
 FROM tweets
 WHERE text LIKE '%#%'
 """, con_ge)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2017         try:
# -> 2018             cur.execute(*args, **kwargs)
#    2019             return cur
#
# OperationalError: near "FROM": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-40-48b9ac7ac276> in <cell line: 1>()
# ----> 1 pd.read_sql_query("""
#       2 SELECT DISTINCT
#       3  FROM tweets
#       4  WHERE text LIKE '%#%'
#       5  """, con_ge)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     395     """
#     396     pandas_sql = pandasSQL_builder(con)
# --> 397     return pandas_sql.read_query(
#     398         sql,
#     399         index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2076
#    2077         args = _convert_params(sql, params)
# -> 2078         cursor = self.execute(*args)
#    2079         columns = [col_desc[0] for col_desc in cursor.description]
#    2080
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2028
#    2029             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2030             raise ex from exc
#    2031
#    2032     @staticmethod
#
# DatabaseError: Execution failed on sql '
# SELECT DISTINCT
#  FROM tweets
#  WHERE text LIKE '%#%'
#  ': near "FROM": syntax error

# %% [markdown]
# # Further data exploration (12 percent)
#
# In this section, you are asked to make further exploration of the data, using the additional data in the repository below (`cand_data.csv`). The data includes the candidate's name, party affiliation, incumbent MP, and screenName. Match this data with the Twitter data, explore the data and describe what you have found using tables, visuals, and/or models.

# %%
# !git clone  https://github.com/University-of-Essex-Dept-of-Government/GV918-UK-politics-data

# %% [markdown]
# I suggest a few questions you can answer (These are just suggestions; you don't have to answer all of them, or you can answer completely different questions):
#
# - Are there any differences in the use of particular hashtags? Which hashtags are more popular among Conservative/Labour candidates? What is the possible reasons for the popularity?
# - Which is the party whose candidates are more likely to tweet? Why do you think that is the case?
# - What are the topics candidates got more replies? Are there party differences (e.g. Labour candidates got more replies to some topics)? Why?
#
# Prepare a proper write-up with more than 500 words.
